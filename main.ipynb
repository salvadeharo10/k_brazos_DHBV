# %% [markdown]
# # 🎰 Trabajo sobre Bandido Multibrazo - Grupo DHBV
# Este notebook principal enlaza y ejecuta los demás notebooks en Google Colab.

# %%
# Clonar el repositorio en Google Colab
# !git clone https://github.com/tu_usuario/k_brazos_DHBV.git
# %cd k_brazos_DHBV

# Instalar paquetes necesarios (si aplica)
# !pip install -r requirements.txt  # Si tienes dependencias

# Semilla para reproducibilidad
import numpy as np
import random
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
print('Repositorio clonado y configurado correctamente.')
